# %% [markdown]
# ## Introduction
#
# This *optimization* file will contain different optimization algorithm, which objective will be to act on the battery in order to reduce the daily electricity bill.
#
# We will first implement a **genetic algorithm**, which proceeds blindly, testing daily battery’s charging and discharging profiles and selecting the ones that lead to better results in terms of savings. Throughout the generations, the best profiles become the “parents”, they originate children by crossing their DNA, and the best children then become the parents of the next generation.

# %%
from ipynb.fs.full.Controller import controller
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt

# %%
class Agent:
    #E_L: daily load, ie client energy consumption
    #E_S: daily solar output
    #SOC_init: inital state of charge of the battery, at t=0
    #k_buy & k_sell: daily electricty buy and sell prices
    
    def __init__(self, E_L, E_S, SOC_init, k_buy, k_sell):
        #initialize daily grid power output instructions
        #only positive for now as I didn't implement the buy from grid equations in the controller
        self.P_G_obj = np.random.randint(0, 50, len(E_L))
        print('initial P_G_obj = ', self.P_G_obj)
        self.fitness = 0
        #initialize daily battery's SOC profile
        SOC_ = np.concatenate((SOC_init, np.zeros(len(E_L)-1)), axis=None)
        
        #calculte the first term, and the initial SOC for the next iteration
        self.P_G_obj[0], SOC_[1], cost_0 = controller(E_L[0], E_S[0], self.P_G_obj[0], SOC_[0],\
                                              k_buy, k_sell)
        self.fitness = cost_0
        
        #calculate all other terms, using previously computed SOC as an input
        for i in range(1, len(self.P_G_obj)):
            self.P_G_obj[i], SOC_[i+1], cost_i  = controller(E_L[i], E_S[i], self.P_G_obj[i], SOC[i], k_buy, k_sell)
            #apply_controller = [controller(E_L[i], E_S[i], self.P_G_obj[i], SOC[i], k_buy, k_sell) for i in range(len(E_L))]    
            
            #fitness has to be low for the profile to be competitive (= low energy cost)
            self.fitness += cost_i
            
        print('P_G_obj after controller = ', self.P_G_obj)
        
        #idky but fitness is a vector, hence we have to sum all its components
        self.fitness = sum(self.fitness)

        print('P_G_obj =',  self.P_G_obj )
        print('fitness =', self.fitness)
        
        #plt.figure()
        #plt.plot(range(len(E_L)), self.P_G_obj)
        #plt.plot(range(len(E_L)), k_buy)
        #plt.title("Oui")
        #plt.legend(['P_G_obj', 'electricity cost'])
    
    
    def _str_(self):
        
        return 'Grid power instruction: ' + self.P_G_obj + ' Fitness :' + str(self.fitness)
    

population = 1
generations = 1

def ga():
    
    agents = init_agents(population, E_L, E_S, SOC, k_buy, k_sell)
    
    for generation in range(generations):
        print('\n')
        print('Generation' + str(generation))
        
        agents = selection(agents)
        agents = crossover(agents)
        agents = mutation(agents)
        
    return sorted(agents, key=lambda agent: agent.fitness, reverse = False)[0].P_G_obj
        
        
def init_agents(population, E_L, E_S, SOC, k_buy, k_sell):
    
    return [Agent(E_L, E_S, SOC,k_buy, k_sell) for _ in range(population)]


def selection(agents):
    print('Agent 0 before sorting', agents[0].P_G_obj, '\n')
    agents = sorted(agents, key=lambda agent: agent.fitness, reverse = False)
    print('Agent 0 after sorting', agents[0].P_G_obj, '\n')
    print(len(agents))
    agents = agents[:int(0.5 * len(agents))]
    print(len(agents))
    
    return agents


def crossover(agents):
        
        offspring = []
        
        for _ in range(int((population - len(agents)) / 2)):
            
            parent1 = np.random.choice(agents)
            parent2 = np.random.choice(agents)
            child1 = Agent(E_L, E_S, SOC, k_buy, k_sell)
            child2 = Agent(E_L, E_S, SOC, k_buy, k_sell)

            split = np.random.randint(0, len(child1.P_G_obj))

            child1.P_G_obj = np.concatenate((parent1.P_G_obj[:split], parent2.P_G_obj[split:]), axis=None)
            child2.P_G_obj = np.concatenate((parent2.P_G_obj[:split], parent1.P_G_obj[split:]), axis=None)

            offspring.append(child1)
            offspring.append(child2)

        agents.extend(offspring)
        
        return agents
        
def mutation(agents):
        
        for agent in agents:
            
            for idx, param in enumerate(agent.P_G_obj):
                
                if np.random.uniform(0.0, 1.0) <= 0.1:
                    
                    agent.P_G_obj = np.concatenate((agent.P_G_obj[:idx], np.random.randint(-50, 50), \
                                                     agent.P_G_obj[idx+1:]), axis=None)
        
        return agents

# %%
population = 10
generations = 100

length = 10
E_L = np.random.randint(0, 50, length)
E_S = np.random.randint(-50, 0, length)
print("E_S = ", E_S)
print("E_L = ", E_L)

print('\n')

SOC_init = 0.1
k_buy = np.random.randint(0, 50, length)
k_sell = k_buy
P_G_obj_test = ga()
# Out:
# E_S =  [-49  -7 -33 -15  -1 -35 -49 -30 -36 -41]
# E_L =  [ 6  0 45 27 12 39 15 44 11  6]
#
#
# initial P_G_obj =  [38 31 18 44 36  8 12 22 36 33]
# P_G_obj after controller =  [38 31 18 44 36  8 12 22 36 33]
# P_G_obj = [38 31 18 44 36  8 12 22 36 33]
# fitness = 4298.033686465378
# initial P_G_obj =  [24 41  1 29 19 31 13 13 11  8]
# P_G_obj after controller =  [24 41  1 29 19 31 13 13 11  8]
# P_G_obj = [24 41  1 29 19 31 13 13 11  8]
# fitness = 41647.00137185971
# initial P_G_obj =  [13 18 23 42 48 42 35  0  7 32]
# P_G_obj after controller =  [13 18 23 42 48 42 35  0  7 32]
# P_G_obj = [13 18 23 42 48 42 35  0  7 32]
# fitness = 19264.17600285615
# initial P_G_obj =  [ 1 32 12 33 27 22 24 11 38 15]
# P_G_obj after controller =  [ 1 32 12 33 27 22 24 11 38 15]
# P_G_obj = [ 1 32 12 33 27 22 24 11 38 15]
# fitness = 29464.028529341052
# initial P_G_obj =  [ 8 33 35 16 28 23 31 39  1  6]
# P_G_obj after controller =  [ 8 33 35 16 28 23 31 39  1  6]
# P_G_obj = [ 8 33 35 16 28 23 31 39  1  6]
# fitness = 40980.170845731824
# initial P_G_obj =  [ 7 11 18 31  7 44  0 30 24 26]
# P_G_obj after controller =  [ 7 11 18 31  7 44  0 30 24 26]
# P_G_obj = [ 7 11 18 31  7 44  0 30 24 26]
# fitness = 40676.991540292045
# initial P_G_obj =  [42 18  7 29 33 31 47 28 38 16]
# P_G_obj after controller =  [42 18  7 29 33 31 47 28 38 16]
# P_G_obj = [42 18  7 29 33 31 47 28 38 16]
# fitness = -6551.573050827694
# initial P_G_obj =  [14 47 33 18 19 47 26 46 31 42]
# P_G_obj after controller =  [14 47 33 18 19 47 26 46 31 42]
# P_G_obj = [14 47 33 18 19 47 26 46 31 42]
# fitness = -152.06462921134914
# initial P_G_obj =  [ 5 39 26  6 32 37 23 31 37 31]
# P_G_obj after controller =  [ 5 39 26  6 32 37 23 31 37 31]
# P_G_obj = [ 5 39 26  6 32 37 23 31 37 31]
# fitness = 14764.323476371246
# initial P_G_obj =  [21 14  2 45 17 30  1 28  1 17]
# P_G_obj after controller =  [21 14  2 45 17 30  1 28  1 17]
# P_G_obj = [21 14  2 45 17 30  1 28  1 17]
# fitness = 49880.0725300551
#
#
# Generation0
# Agent 0 before sorting [38 31 18 44 36  8 12 22 36 33]
#
# Agent 0 after sorting [42 18  7 29 33 31 47 28 38 16]
#
# 10
# 5
# initial P_G_obj =  [ 0 30 25 47 27 38 34 48 15 48]
# P_G_obj after controller =  [ 0 30 25 47 27 38 34 48 15 48]
# P_G_obj = [ 0 30 25 47 27 38 34 48 15 48]
# fitness = 7631.006528984037
# initial P_G_obj =  [ 9 29 42 22  8  4  9 19  0 23]
# P_G_obj after controller =  [ 9 29 42 22  8  4  9 19  0 23]
# P_G_obj = [ 9 29 42 22  8  4  9 19  0 23]
# fitness = 51146.755582667894
# initial P_G_obj =  [28 16 18 47 22 44 30 17 33 27]
# P_G_obj after controller =  [28 16 18 47 22 44 30 17 33 27]
# P_G_obj = [28 16 18 47 22 44 30 17 33 27]
# fitness = 4081.350633852586
# initial P_G_obj =  [46 44 33 10 46 29  5  0 28 38]
# P_G_obj after controller =  [46 44 33 10 46 29  5  0 28 38]
# P_G_obj = [46 44 33 10 46 29  5  0 28 38]
# fitness = 4914.667581239799
#
#
# Generation1
# Agent 0 before sorting [42 18  7 29 33 31 47 28 38 16]
#
# Agent 0 after sorting [42 18  7 29 33 31 47 28 38 16]
#
# 9
# 4
# initial P_G_obj =  [49 20 37 35 33 30 37  3  9 27]
# P_G_obj after controller =  [49 20 37 35 33 30 37  3  9 27]
# P_G_obj = [49 20 37 35 33 30 37  3  9 27]
# fitness = 2848.082844303742
# initial P_G_obj =  [ 7 40 29 34 22 25 23  1 36  6]
# P_G_obj after controller =  [ 7 40 29 34 22 25 23  1 36  6]
# P_G_obj = [ 7 40 29 34 22 25 23  1 36  6]
# fitness = 30563.930213664327
# initial P_G_obj =  [47 22 25  2 42 17 27 30 37 31]
# P_G_obj after controller =  [47 22 25  2 42 17 27 30 37 31]
# P_G_obj = [47 22 25  2 42 17 27 30 37 31]
# fitness = -4818.256103440484
# initial P_G_obj =  [21  9  9 48 38  4 22 37  5 33]
# P_G_obj after controller =  [21  9  9 48 38  4 22 37  5 33]
# P_G_obj = [21  9  9 48 38  4 22 37  5 33]
# fitness = 28044.01869777337
# initial P_G_obj =  [39 16 32  9 30 19 17 16  7 38]
# P_G_obj after controller =  [39 16 32  9 30 19 17 16  7 38]
# P_G_obj = [39 16 32  9 30 19 17 16  7 38]
# fitness = 19447.738739435194
# initial P_G_obj =  [46 12 45 40 17 25 27  2 27 48]
# P_G_obj after controller =  [46 12 45 40 17 25 27  2 27 48]
# P_G_obj = [46 12 45 40 17 25 27  2 27 48]
# fitness = -8238.167619331429
#
#
# Generation2
# Agent 0 before sorting [42 18  7 29 33 31 47 28 38 16]
#
# Agent 0 after sorting [14 47 33 18 19 47 26 45 31 42]
#
# 10
# 5
# initial P_G_obj =  [44 36 17 24  3 37  9 22  0 43]
# P_G_obj after controller =  [44 36 17 24  3 37  9 22  0 43]
# P_G_obj = [44 36 17 24  3 37  9 22  0 43]
# fitness = 19564.323476371246
# initial P_G_obj =  [37 35 20 28 27  5 34 13 16 43]
# P_G_obj after controller =  [37 35 20 28 27  5 34 13 16 43]
# P_G_obj = [37 35 20 28 27  5 34 13 16 43]
# fitness = 3081.547265206051
# initial P_G_obj =  [40 35 41 43 32  4  9 27 14 46]
# P_G_obj after controller =  [40 35 41 43 32  4  9 27 14 46]
# P_G_obj = [40 35 41 43 32  4  9 27 14 46]
# fitness = 6181.203160337494
# initial P_G_obj =  [41 39  6 34  4 17  1 49  9 17]
# P_G_obj after controller =  [41 39  6 34  4 17  1 49  9 17]
# P_G_obj = [41 39  6 34  4 17  1 49  9 17]
# fitness = 32997.19800321317
#
#
# Generation3
# Agent 0 before sorting [ 14  47  33   4  19  47  26  45  31 -20]
#
# Agent 0 after sorting [ 14  47  33   4  19  47  26  45  31 -20]
#
# 9
# 4
# initial P_G_obj =  [31 40 22  4 30  2  2 41 34  3]
# P_G_obj after controller =  [31 40 22  4 30  2  2 41 34  3]
# P_G_obj = [31 40 22  4 30  2  2 41 34  3]
# fitness = 33430.56410843875
# initial P_G_obj =  [30 30 44 45 33  3 45 14 32 49]
# P_G_obj after controller =  [30 30 44 45 33  3 45 14 32 49]
# P_G_obj = [30 30 44 45 33  3 45 14 32 49]
# fitness = -16934.693366861455
# initial P_G_obj =  [46 32 17 20 38 38 32 26 37 16]
# P_G_obj after controller =  [46 32 17 20 38 38 32 26 37 16]
# P_G_obj = [46 32 17 20 38 38 32 26 37 16]
# fitness = -3901.769682181158
# initial P_G_obj =  [46 22 20 41 20  7 37 36 25  4]
# P_G_obj after controller =  [46 22 20 41 20  7 37 36 25  4]
# P_G_obj = [46 22 20 41 20  7 37 36 25  4]
# fitness = 9981.252318175859
# initial P_G_obj =  [37 22 14 29 17 26 19 18 18  3]
# P_G_obj after controller =  [37 22 14 29 17 26 19 18 18  3]
# P_G_obj = [37 22 14 29 17 26 19 18 18  3]
# fitness = 31647.345476728264
# initial P_G_obj =  [12  6 33 28 40 44  0 24  6 37]
# P_G_obj after controller =  [12  6 33 28 40 44  0 24  6 37]
# P_G_obj = [12  6 33 28 40 44  0 24  6 37]
# fitness = 38560.210172002524
#
#
# Generation4
# Agent 0 before sorting [ 14  47  33   4  19  47  26  45  31 -20]
#
# Agent 0 after sorting [ 14  47   7  29 -28  31  47  28  38  16]
#
# 10
# 5
# initial P_G_obj =  [33  8 32 23  7 43 32 21 45 22]
# P_G_obj after controller =  [ 33   8  32  23   7  43  32  21 -36  22]
# P_G_obj = [ 33   8  32  23   7  43  32  21 -36  22]
# fitness = 16002.183192373124
# initial P_G_obj =  [ 9 20 10  1  3 32 32 31 28 28]
# P_G_obj after controller =  [ 9 20 10  1  3 32 32 31 28 28]
# P_G_obj = [ 9 20 10  1  3 32 32 31 28 28]
# fitness = 25331.006528984035
# initial P_G_obj =  [ 7  2 34 35 20  7 40  7 42 13]
# P_G_obj after controller =  [ 7  2 34 35 20  7 40  7 42 13]
# P_G_obj = [ 7  2 34 35 20  7 40  7 42 13]
# fitness = 25527.58143435243
# initial P_G_obj =  [ 7  4  3 10 16 11 20  5 11 37]
# P_G_obj after controller =  [ 7  4  3 10 16 11 20  5 11 37]
# P_G_obj = [ 7  4  3 10 16 11 20  5 11 37]
# fitness = 47560.50511903271
#
#
# Generation5
# Agent 0 before sorting [ 14  47  20  29 -28  31  47  28  38  16]
#
# Agent 0 after sorting [ 14  47  20  29 -28  31  47  28  38  16]
#
# 9
# 4
# initial P_G_obj =  [28  2 43 42 13 33 15 18 35 43]
# P_G_obj after controller =  [28  2 43 42 13 33 15 18 35 43]
# P_G_obj = [28  2 43 42 13 33 15 18 35 43]
# fitness = 8494.559433995395
# initial P_G_obj =  [ 2 35 38 35 47 19 39 22 35 21]
# P_G_obj after controller =  [ 2 35 38 35 47 19 39 22 35 21]
# P_G_obj = [ 2 35 38 35 47 19 39 22 35 21]
# fitness = 10481.006528984031
# initial P_G_obj =  [18 41  2  7 27 40 37 22  0 33]
# P_G_obj after controller =  [18 41  2  7 27 40 37 22  0 33]
# P_G_obj = [18 41  2  7 27 40 37 22  0 33]
# fitness = 23830.859055468936
# initial P_G_obj =  [ 4 38  7 12  5 16 16 12  6 12]
# P_G_obj after controller =  [ 4 38  7 12  5 16 16 12  6 12]
# P_G_obj = [ 4 38  7 12  5 16 16 12  6 12]
# fitness = 57846.70642482953
# initial P_G_obj =  [ 3 28 29 10 39 45 48 19 47  8]
# P_G_obj after controller =  [  3  28  29  10  39  45  48  19 -36   8]
# P_G_obj = [  3  28  29  10  39  45  48  19 -36   8]
# fitness = 23771.799761233888
# initial P_G_obj =  [40 10 41 35 48  8 43 25  2 42]
# P_G_obj after controller =  [40 10 41 35 48  8 43 25  2 42]
# P_G_obj = [40 10 41 35 48  8 43 25  2 42]
# fitness = -171.87782942556862
#
#
# Generation6
# Agent 0 before sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# Agent 0 after sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# 10
# 5
# initial P_G_obj =  [44 27  8  8 32 45 12  9 14  6]
# P_G_obj after controller =  [44 27  8  8 32 45 12  9 14  6]
# P_G_obj = [44 27  8  8 32 45 12  9 14  6]
# fitness = 31730.662424115475
# initial P_G_obj =  [ 0  1  8 46 25 22 31 30 10  5]
# P_G_obj after controller =  [ 0  1  8 46 25 22 31 30 10  5]
# P_G_obj = [ 0  1  8 46 25 22 31 30 10  5]
# fitness = 51726.64743542349
# initial P_G_obj =  [48 19 48 24 48 24 49 43 29  6]
# P_G_obj after controller =  [48 19 48 24 48 24 49 43 29  6]
# P_G_obj = [48 19 48 24 48 24 49 43 29  6]
# fitness = -9685.086629568368
# initial P_G_obj =  [48 11 32 42 42  7 30 19 30 47]
# P_G_obj after controller =  [48 11 32 42 42  7 30 19 30 47]
# P_G_obj = [48 11 32 42 42  7 30 19 30 47]
# fitness = -13388.069303654702
#
#
# Generation7
# Agent 0 before sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# Agent 0 after sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# 9
# 4
# initial P_G_obj =  [13  0  9  1 43 19 28 46 44 35]
# P_G_obj after controller =  [ 13   0   9   1  43  19  28  46 -36  35]
# P_G_obj = [ 13   0   9   1  43  19  28  46 -36  35]
# fitness = 27335.20519273015
# initial P_G_obj =  [30 23 37 29 46  2 25 22 37 33]
# P_G_obj after controller =  [30 23 37 29 46  2 25 22 37 33]
# P_G_obj = [30 23 37 29 46  2 25 22 37 33]
# fitness = 1098.1320021421034
# initial P_G_obj =  [48 41  2  1 25 43 24 36 32  9]
# P_G_obj after controller =  [48 41  2  1 25 43 24 36 32  9]
# P_G_obj = [48 41  2  1 25 43 24 36 32  9]
# fitness = 9147.935370788646
# initial P_G_obj =  [11 44 29 42 48 35  1 34  7 35]
# P_G_obj after controller =  [11 44 29 42 48 35  1 34  7 35]
# P_G_obj = [11 44 29 42 48 35  1 34  7 35]
# fitness = 28013.63526663413
# initial P_G_obj =  [18  0 38 49 25 45 19 48 21 48]
# P_G_obj after controller =  [18  0 38 49 25 45 19 48 21 48]
# P_G_obj = [18  0 38 49 25 45 19 48 21 48]
# fitness = 9160.947539577992
# initial P_G_obj =  [ 1 25 34 18 10  9 49 27  5  1]
# P_G_obj after controller =  [ 1 25 34 18 10  9 49 27  5  1]
# P_G_obj = [ 1 25 34 18 10  9 49 27  5  1]
# fitness = 43297.001371859726
#
#
# Generation8
# Agent 0 before sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# Agent 0 after sorting [ 14  47  20  29 -28 -39  -4  28  38  16]
#
# 10
# 5
# initial P_G_obj =  [32 44 26 46 34 34 13  3 43 13]
# P_G_obj after controller =  [ 32  44  26  46  34  34  13   3 -36  13]
# P_G_obj = [ 32  44  26  46  34  34  13   3 -36  13]
# fitness = 21755.116708621084
# initial P_G_obj =  [28 16 49 32  3 11 11 12  5 40]
# P_G_obj after controller =  [28 16 49 32  3 11 11 12  5 40]
# P_G_obj = [28 16 49 32  3 11 11 12  5 40]
# fitness = 28364.126845017785
# initial P_G_obj =  [19 32 33 26 15 49 34 29 35  6]
# P_G_obj after controller =  [19 32 33 26 15 49 34 29 35  6]
# P_G_obj = [19 32 33 26 15 49 34 29 35  6]
# fitness = 13880.957371145669
# initial P_G_obj =  [ 2 49 38 46 11 38 10 17 29 35]
# P_G_obj after controller =  [ 2 49 38 46 11 38 10 17 29 35]
# P_G_obj = [ 2 49 38 46 11 38 10 17 29 35]
# fitness = 21230.66242411547
#
#
# Generation9
# Agent 0 before sorting [ -3  47  20  29 -28 -39  -9  28  38  16]
#
# Agent 0 after sorting [ -3  47  20  29 -28 -39  -9  28  38  16]
#
# 9
# 4
# initial P_G_obj =  [45 30 38 37  6 17 19 42 40 11]
# P_G_obj after controller =  [45 30 38 37  6 17 19 42 40 11]
# P_G_obj = [45 30 38 37  6 17 19 42 40 11]
# fitness = 4781.30147601422
# initial P_G_obj =  [27 22 12 45 35 31 24 29 11 30]
# P_G_obj after controller =  [27 22 12 45 35 31 24 29 11 30]
# P_G_obj = [27 22 12 45 35 31 24 29 11 30]
# fitness = 16447.59126592009
# initial P_G_obj =  [34  7  5  8  7 45 29  6 32 37]
# P_G_obj after controller =  [34  7  5  8  7 45 29  6 32 37]
# P_G_obj = [34  7  5  8  7 45 29  6 32 37]
# fitness = 11661.488275800013
# initial P_G_obj =  [20  0 40 37 22 22 26 20 49  3]
# P_G_obj after controller =  [ 20   0  40  37  22  22  26  20 -36   3]
# P_G_obj = [ 20   0  40  37  22  22  26  20 -36   3]
# fitness = 38284.76277218487
# initial P_G_obj =  [27  1  9 33 21 42 41 20 31 44]
# P_G_obj after controller =  [27  1  9 33 21 42 41 20 31 44]
# P_G_obj = [27  1  9 33 21 42 41 20 31 44]
# fitness = 894.903538863954
# initial P_G_obj =  [20  2 27 36 46 24 40 28 48 12]
# P_G_obj after controller =  [ 20   2  27  36  46  24  40  28 -36  12]
# P_G_obj = [ 20   2  27  36  46  24  40  28 -36  12]
# fitness = 21951.83908750458
#
#
# Generation10
# Agent 0 before sorting [ -3  47  20  29 -28  -5 -27  28  38  16]
#
# Agent 0 after sorting [ -3  47  20  29 -28  -5 -27  28  38  16]
#
# 10
# 5
# initial P_G_obj =  [40 17 16 10 11 13 39  2 23 38]
# P_G_obj after controller =  [40 17 16 10 11 13 39  2 23 38]
# P_G_obj = [40 17 16 10 11 13 39  2 23 38]
# fitness = 6598.377791333939
# initial P_G_obj =  [24 18 29 37 31 33  9 37 18 14]
# P_G_obj after controller =  [24 18 29 37 31 33  9 37 18 14]
# P_G_obj = [24 18 29 37 31 33  9 37 18 14]
# fitness = 29197.1488453748
# initial P_G_obj =  [33 34 19 33  8 30 27 39  0 34]
# P_G_obj after controller =  [33 34 19 33  8 30 27 39  0 34]
# P_G_obj = [33 34 19 33  8 30 27 39  0 34]
# fitness = 17030.95737114567
# initial P_G_obj =  [23 38  9 38 11 21 46  9 39 16]
# P_G_obj after controller =  [23 38  9 38 11 21 46  9 39 16]
# P_G_obj = [23 38  9 38 11 21 46  9 39 16]
# fitness = 6581.448949529321
#
#
# Generation11
# Agent 0 before sorting [ -3  47  20   0  37  -5 -27  28  38 -28]
#
# Agent 0 after sorting [ -3  47  20   0  37  -5 -27  28  38 -28]
#
# 9
# 4
# initial P_G_obj =  [45 26  4 44  6  1 11  9  8 41]
# P_G_obj after controller =  [45 26  4 44  6  1 11  9  8 41]
# P_G_obj = [45 26  4 44  6  1 11  9  8 41]
# fitness = 22114.470949886345
# initial P_G_obj =  [ 2 44 15 21 49 44  7 47 24  3]
# P_G_obj after controller =  [ 2 44 15 21 49 44  7 47 24  3]
# P_G_obj = [ 2 44 15 21 49 44  7 47 24  3]
# fitness = 39413.34031960395
# initial P_G_obj =  [15  2 31 47 25 48 30 22 49 20]
# P_G_obj after controller =  [ 15   2  31  47  25  48  30  22 -36  20]
# P_G_obj = [ 15   2  31  47  25  48  30  22 -36  20]
# fitness = 23885.05771921506
# initial P_G_obj =  [28 13 24 22 45 10 31 39 36  1]
# P_G_obj after controller =  [28 13 24 22 45 10 31 39 36  1]
# P_G_obj = [28 13 24 22 45 10 31 39 36  1]
# fitness = 17464.32347637125
# initial P_G_obj =  [46 15 37 32 49 13 21 10 24 20]
# P_G_obj after controller =  [46 15 37 32 49 13 21 10 24 20]
# P_G_obj = [46 15 37 32 49 13 21 10 24 20]
# fitness = 9014.569265563065
# initial P_G_obj =  [ 0  9 31 25 13 40 37 31 11  8]
# P_G_obj after controller =  [ 0  9 31 25 13 40 37 31 11  8]
# P_G_obj = [ 0  9 31 25 13 40 37 31 11  8]
# fitness = 40776.94238245368
#
#
# Generation12
# Agent 0 before sorting [-46  47  20   0  37  -5 -27  28  38 -28]
#
# Agent 0 after sorting [-46  47  20   0  37  -5 -27  28  38 -28]
#
# 10
# 5
# initial P_G_obj =  [ 7 49 16 47  0 47 22  6 48 16]
# P_G_obj after controller =  [  7  49  16  47   0  47  22   6 -36  16]
# P_G_obj = [  7  49  16  47   0  47  22   6 -36  16]
# fitness = 31988.237024654845
# initial P_G_obj =  [30 12 16 43 41  8 43 18 49 32]
# P_G_obj after controller =  [ 30  12  16  43  41   8  43  18 -36  32]
# P_G_obj = [ 30  12  16  43  41   8  43  18 -36  32]
# fitness = 4269.210349854471
# initial P_G_obj =  [33 22 34  6 22 29 29 16 39 47]
# P_G_obj after controller =  [33 22 34  6 22 29 29 16 39 47]
# P_G_obj = [33 22 34  6 22 29 29 16 39 47]
# fitness = -6668.157787763757
# initial P_G_obj =  [10  4 46 33 19 32  3 47 16 26]
# P_G_obj after controller =  [10  4 46 33 19 32  3 47 16 26]
# P_G_obj = [10  4 46 33 19 32  3 47 16 26]
# fitness = 38426.84406677695
#
#
# Generation13
# Agent 0 before sorting [-46  47  20 -50  37  -5 -27  28  38  11]
#
# Agent 0 after sorting [-46  47  20 -50  37  -5 -27  28  38  11]
#
# 9
# 4
# initial P_G_obj =  [18 32 43 12 40 33 36 25 44 26]
# P_G_obj after controller =  [ 18  32  43  12  40  33  36  25 -36  26]
# P_G_obj = [ 18  32  43  12  40  33  36  25 -36  26]
# fitness = 10322.14386610244
# initial P_G_obj =  [10  5 39 38 36  1 44 12 31 31]
# P_G_obj after controller =  [10  5 39 38 36  1 44 12 31 31]
# P_G_obj = [10  5 39 38 36  1 44 12 31 31]
# fitness = 13011.193328769825
# initial P_G_obj =  [17 16 33 38 20 11 17 40  7 30]
# P_G_obj after controller =  [17 16 33 38 20 11 17 40  7 30]
# P_G_obj = [17 16 33 38 20 11 17 40  7 30]
# fitness = 30047.247161051542
# initial P_G_obj =  [ 5 34  2  8 20 43 27 35 40 33]
# P_G_obj after controller =  [ 5 34  2  8 20 43 27 35 40 33]
# P_G_obj = [ 5 34  2  8 20 43 27 35 40 33]
# fitness = 14314.470949886341
# initial P_G_obj =  [42 20 31 27 43 37 48 24 13 39]
# P_G_obj after controller =  [42 20 31 27 43 37 48 24 13 39]
# P_G_obj = [42 20 31 27 43 37 48 24 13 39]
# fitness = -11418.256103440488
# initial P_G_obj =  [ 7  6 10  2 49 20 49 24 49 45]
# P_G_obj after controller =  [  7   6  10   2  49  20  49  24 -36  45]
# P_G_obj = [  7   6  10   2  49  20  49  24 -36  45]
# fitness = 12752.379823726593
#
#
# Generation14
# Agent 0 before sorting [-46  47  20 -50  37  -5 -27  28  38 -38]
#
# Agent 0 after sorting [-46  47  20 -50  37  -5 -27  28  38 -38]
#
# 10
# 5
# initial P_G_obj =  [ 4 18 40  2  1 34 35 11 33 29]
# P_G_obj after controller =  [ 4 18 40  2  1 34 35 11 33 29]
# P_G_obj = [ 4 18 40  2  1 34 35 11 33 29]
# fitness = 21847.73873943518
# initial P_G_obj =  [30  6 23 41 48 14 15 32 27 35]
# P_G_obj after controller =  [30  6 23 41 48 14 15 32 27 35]
# P_G_obj = [30  6 23 41 48 14 15 32 27 35]
# fitness = 12477.728907867508
# initial P_G_obj =  [10 23 41 37 42 27 19 44 44 33]
# P_G_obj after controller =  [ 10  23  41  37  42  27  19  44 -36  33]
# P_G_obj = [ 10  23  41  37  42  27  19  44 -36  33]
# fitness = 15571.848919072243
# initial P_G_obj =  [44  7 31 27 47 18 16 49 11 27]
# P_G_obj after controller =  [44  7 31 27 47 18 16 49 11 27]
# P_G_obj = [44  7 31 27 47 18 16 49 11 27]
# fitness = 14644.26448696521
#
#
# Generation15
# Agent 0 before sorting [-46  47  20 -50  37  -5 -27  16  38 -38]
#
# Agent 0 after sorting [-46  47  20 -50  37  -5 -27  16  38 -38]
#
# 9
# 4
# initial P_G_obj =  [19 23 49 34 15 39 22 37 31  6]
# P_G_obj after controller =  [19 23 49 34 15 39 22 37 31  6]
# P_G_obj = [19 23 49 34 15 39 22 37 31  6]
# fitness = 20464.028529341052
# initial P_G_obj =  [20 12 25  2 20 38 13 44 36 19]
# P_G_obj after controller =  [20 12 25  2 20 38 13 44 36 19]
# P_G_obj = [20 12 25  2 20 38 13 44 36 19]
# fitness = 23760.849223901267
# initial P_G_obj =  [33 35 23  3 29 33 35 11 17 29]
# P_G_obj after controller =  [33 35 23  3 29 33 35 11 17 29]
# P_G_obj = [33 35 23  3 29 33 35 11 17 29]
# fitness = 10714.618423401433
# initial P_G_obj =  [49 27  2 36 22 47 42 38 38 39]
# P_G_obj after controller =  [49 27  2 36 22 47 42 38 38 39]
# P_G_obj = [49 27  2 36 22 47 42 38 38 39]
# fitness = -23784.49673550799
# initial P_G_obj =  [ 0 10 29 48 38 13 44  5 29 31]
# P_G_obj after controller =  [ 0 10 29 48 38 13 44  5 29 31]
# P_G_obj = [ 0 10 29 48 38 13 44  5 29 31]
# fitness = 15694.411960480309
# initial P_G_obj =  [38 13 10 34  3 26 17 32 18 29]
# P_G_obj after controller =  [38 13 10 34  3 26 17 32 18 29]
# P_G_obj = [38 13 10 34  3 26 17 32 18 29]
# fitness = 19514.42179204798
#
#
# Generation16
# Agent 0 before sorting [-46  47  20 -50  37  -5 -27 -49  38 -38]
#
# Agent 0 after sorting [ 14  47  33   2 -38  47  20 -23  46 -20]
#
# 10
# 5
# initial P_G_obj =  [46 39 29 44 24 15 32  6  5  4]
# P_G_obj after controller =  [46 39 29 44 24 15 32  6  5  4]
# P_G_obj = [46 39 29 44 24 15 32  6  5  4]
# fitness = 21664.176002856148
# initial P_G_obj =  [15  4  8 47  2 16  4 44 42 44]
# P_G_obj after controller =  [15  4  8 47  2 16  4 44 42 44]
# P_G_obj = [15  4  8 47  2 16  4 44 42 44]
# fitness = 20760.99669741636
# initial P_G_obj =  [25 43  5 23  6 26 45  0 23 18]
# P_G_obj after controller =  [25 43  5 23  6 26 45  0 23 18]
# P_G_obj = [25 43  5 23  6 26 45  0 23 18]
# fitness = 16964.569265563077
# initial P_G_obj =  [ 5 25 36  2  3 46 40 41  1  6]
# P_G_obj after controller =  [ 5 25 36  2  3 46 40 41  1  6]
# P_G_obj = [ 5 25 36  2  3 46 40 41  1  6]
# fitness = 40930.26916140857
#
#
# Generation17
# Agent 0 before sorting [ 14  47  33   2 -38  13  20 -23  46 -20]
#
# Agent 0 after sorting [ 14  47  33   2 -38  13  20 -23  46 -20]
#
# 9
# 4
# initial P_G_obj =  [40 10 12 42 29 43 26 36 45  3]
# P_G_obj after controller =  [ 40  10  12  42  29  43  26  36 -36   3]
# P_G_obj = [ 40  10  12  42  29  43  26  36 -36   3]
# fitness = 19135.25435056852
# initial P_G_obj =  [ 6 48 36 29 44 31 21 37 36 29]
# P_G_obj after controller =  [ 6 48 36 29 44 31 21 37 36 29]
# P_G_obj = [ 6 48 36 29 44 31 21 37 36 29]
# fitness = 8797.591265920088
# initial P_G_obj =  [ 5  0  2 33 28 45 29 28 10 45]
# P_G_obj after controller =  [ 5  0  2 33 28 45 29 28 10 45]
# P_G_obj = [ 5  0  2 33 28 45 29 28 10 45]
# fitness = 28577.335645160598
# initial P_G_obj =  [10 18  8 34 15 34 48 25 47  5]
# P_G_obj after controller =  [ 10  18   8  34  15  34  48  25 -36   5]
# P_G_obj = [ 10  18   8  34  15  34  48  25 -36   5]
# fitness = 27038.531971685035
# initial P_G_obj =  [34 28 35 25 40 33 28 40  1  4]
# P_G_obj after controller =  [34 28 35 25 40 33 28 40  1  4]
# P_G_obj = [34 28 35 25 40 33 28 40  1  4]
# fitness = 25730.514950600376
# initial P_G_obj =  [42  8 17 46  3 47 17  4 37 23]
# P_G_obj after controller =  [42  8 17 46  3 47 17  4 37 23]
# P_G_obj = [42  8 17 46  3 47 17  4 37 23]
# fitness = 11161.291644446554
#
#
# Generation18
# Agent 0 before sorting [ 14  47  33   2 -38  13  20 -23  36 -20]
#
# Agent 0 after sorting [ 14  47  33   2 -38  13  20 -23  36 -20]
#
# 10
# 5
# initial P_G_obj =  [14 21 43  6 33 47 23 19  5 40]
# P_G_obj after controller =  [14 21 43  6 33 47 23 19  5 40]
# P_G_obj = [14 21 43  6 33 47 23 19  5 40]
# fitness = 22530.760739792207
# initial P_G_obj =  [23 19  3 35  7 46 12  5 41 43]
# P_G_obj after controller =  [23 19  3 35  7 46 12  5 41 43]
# P_G_obj = [23 19  3 35  7 46 12  5 41 43]
# fitness = 10898.033686465378
# initial P_G_obj =  [44 41 40 19 33 44 13 46  9 26]
# P_G_obj after controller =  [44 41 40 19 33 44 13 46  9 26]
# P_G_obj = [44 41 40 19 33 44 13 46  9 26]
# fitness = 9097.591265920097
# initial P_G_obj =  [ 8 41 23  4  5 30  5 16 22 33]
# P_G_obj after controller =  [ 8 41 23  4  5 30  5 16 22 33]
# P_G_obj = [ 8 41 23  4  5 30  5 16 22 33]
# fitness = 37497.19800321317
#
#
# Generation19
# Agent 0 before sorting [ 14 -28  33   2 -38  13  20 -23  44 -20]
#
# Agent 0 after sorting [ 14 -28  33   2 -38  13  20 -23  44 -20]
#
# 9
# 4
# initial P_G_obj =  [30 10 49 26 40 29 39 42 31 19]
# P_G_obj after controller =  [30 10 49 26 40 29 39 42 31 19]
# P_G_obj = [30 10 49 26 40 29 39 42 31 19]
# fitness = -255.34225032787356
# initial P_G_obj =  [37 15 44 21 48 23  4  3 14 44]
# P_G_obj after controller =  [37 15 44 21 48 23  4  3 14 44]
# P_G_obj = [37 15 44 21 48 23  4  3 14 44]
# fitness = 15714.372634209607
# initial P_G_obj =  [13 25 21 49 10 15 15 26 10  7]
# P_G_obj after controller =  [13 25 21 49 10 15 15 26 10  7]
# P_G_obj = [13 25 21 49 10 15 15 26 10  7]
# fitness = 45713.48779311905
# initial P_G_obj =  [35 37 10 26  2  4 23 30  0 35]
# P_G_obj after controller =  [35 37 10 26  2  4 23 30  0 35]
# P_G_obj = [35 37 10 26  2  4 23 30  0 35]
# fitness = 25664.27431853288
# initial P_G_obj =  [10 29 25 44  5 18 18 42 45 42]
# P_G_obj after controller =  [ 10  29  25  44   5  18  18  42 -36  42]
# P_G_obj = [ 10  29  25  44   5  18  18  42 -36  42]
# fitness = 18955.31333997455
# initial P_G_obj =  [47 17 46 42 13  3 29 34  7 44]
# P_G_obj after controller =  [47 17 46 42 13  3 29 34  7 44]
# P_G_obj = [47 17 46 42 13  3 29 34  7 44]
# fitness = 631.4981073676887
#
#
# Generation20
# Agent 0 before sorting [ 14 -28  33   2  40  13  20 -23  44  44]
#
# Agent 0 after sorting [ 14 -28  33   2  40  13  20 -23  44  44]
#
# 10
# 5
# initial P_G_obj =  [40 39 33 39 47 11 11 42 17  3]
# P_G_obj after controller =  [40 39 33 39 47 11 11 42 17  3]
# P_G_obj = [40 39 33 39 47 11 11 42 17  3]
# fitness = 22097.24716105153
# initial P_G_obj =  [ 6 22  8 48 44 18  2 21  7 33]
# P_G_obj after controller =  [ 6 22  8 48 44 18  2 21  7 33]
# P_G_obj = [ 6 22  8 48 44 18  2 21  7 33]
# fitness = 41863.5369509574
# initial P_G_obj =  [42 36 41  9 25 48 24  6 45  8]
# P_G_obj after controller =  [ 42  36  41   9  25  48  24   6 -36   8]
# P_G_obj = [ 42  36  41   9  25  48  24   6 -36   8]
# fitness = 16522.045550425708
# initial P_G_obj =  [36 40 16  0 48 37  4 31 18 32]
# P_G_obj after controller =  [36 40 16  0 48 37  4 31 18 32]
# P_G_obj = [36 40 16  0 48 37  4 31 18 32]
# fitness = 17814.225160694514
#
#
# Generation21
# Agent 0 before sorting [ 14 -28  33   2  40  13   5 -23  44  44]
#
# Agent 0 after sorting [ 14 -28  33   2  40  13   5 -23  44  44]
#
# 9
# 4
# initial P_G_obj =  [19 25 13  2 14 36 30 46 17 20]
# P_G_obj after controller =  [19 25 13  2 14 36 30 46 17 20]
# P_G_obj = [19 25 13  2 14 36 30 46 17 20]
# fitness = 25347.49295024336
# initial P_G_obj =  [28 40  3 27 18 14  4 31 25 37]
# P_G_obj after controller =  [28 40  3 27 18 14  4 31 25 37]
# P_G_obj = [28 40  3 27 18 14  4 31 25 37]
# fitness = 21530.95737114567
# initial P_G_obj =  [ 6 42 13  4  3 24 10 28 28  0]
# P_G_obj after controller =  [ 6 42 13  4  3 24 10 28 28  0]
# P_G_obj = [ 6 42 13  4  3 24 10 28 28  0]
# fitness = 51046.80474050626
# initial P_G_obj =  [17 30 22  3 38 14  9 32 27 17]
# P_G_obj after controller =  [17 30 22  3 38 14  9 32 27 17]
# P_G_obj = [17 30 22  3 38 14  9 32 27 17]
# fitness = 33430.564108438746
# initial P_G_obj =  [34  5  1 15 15 47  2 16 45 25]
# P_G_obj after controller =  [ 34   5   1  15  15  47   2  16 -36  25]
# P_G_obj = [ 34   5   1  15  15  47   2  16 -36  25]
# fitness = 36268.37466660226
# initial P_G_obj =  [22 25 21 22  8  8 10 32  6 18]
# P_G_obj after controller =  [22 25 21 22  8  8 10 32  6 18]
# P_G_obj = [22 25 21 22  8  8 10 32  6 18]
# fitness = 44347.00137185972
#
#
# Generation22
# Agent 0 before sorting [ 14 -28  33   2 -49  13   5 -23  44  44]
#
# Agent 0 after sorting [ 14 -28  33   2 -49  13   5 -23  44  44]
#
# 10
# 5
# initial P_G_obj =  [31  7 10 46 13 38 13 42 15 28]
# P_G_obj after controller =  [31  7 10 46 13 38 13 42 15 28]
# P_G_obj = [31  7 10 46 13 38 13 42 15 28]
# fitness = 23960.750908224534
# initial P_G_obj =  [32 17 43 30  2 21 44 16 26 11]
# P_G_obj after controller =  [32 17 43 30  2 21 44 16 26 11]
# P_G_obj = [32 17 43 30  2 21 44 16 26 11]
# fitness = 11997.935370788638
# initial P_G_obj =  [27 37 25 35 19 10 21 21 42 33]
# P_G_obj after controller =  [27 37 25 35 19 10 21 21 42 33]
# P_G_obj = [27 37 25 35 19 10 21 21 42 33]
# fitness = 3964.765896916525
# initial P_G_obj =  [ 9 10 43 15 38 44 15  3 17 47]
# P_G_obj after controller =  [ 9 10 43 15 38 44 15  3 17 47]
# P_G_obj = [ 9 10 43 15 38 44 15  3 17 47]
# fitness = 22727.483118675696
#
#
# Generation23
# Agent 0 before sorting [ 14 -28  33   1 -49  13   5 -23  44  44]
#
# Agent 0 after sorting [ 14 -28  33   1 -49  13   5 -23  44  44]
#
# 9
# 4
# initial P_G_obj =  [22 41  3  2 32 24 28 35 37 49]
# P_G_obj after controller =  [22 41  3  2 32 24 28 35 37 49]
# P_G_obj = [22 41  3  2 32 24 28 35 37 49]
# fitness = -1468.354419117222
# initial P_G_obj =  [30 43 20 38 35 49 34 32  5 19]
# P_G_obj after controller =  [30 43 20 38 35 49 34 32  5 19]
# P_G_obj = [30 43 20 38 35 49 34 32  5 19]
# fitness = 12130.859055468936
# initial P_G_obj =  [42  5  8 29 11 34 23  0  5 47]
# P_G_obj after controller =  [42  5  8 29 11 34 23  0  5 47]
# P_G_obj = [42  5  8 29 11 34 23  0  5 47]
# fitness = 19077.876381382608
# initial P_G_obj =  [36 16 29 20 39 45 49 47 20 21]
# P_G_obj after controller =  [36 16 29 20 39 45 49 47 20 21]
# P_G_obj = [36 16 29 20 39 45 49 47 20 21]
# fitness = -4985.184945245104
# initial P_G_obj =  [33  7 20 10 20 48  7  6 14  3]
# P_G_obj after controller =  [33  7 20 10 20 48  7  6 14  3]
# P_G_obj = [33  7 20 10 20 48  7  6 14  3]
# fitness = 46710.25932984089
# initial P_G_obj =  [17  2 47 19 23  2 10 35  2 31]
# P_G_obj after controller =  [17  2 47 19 23  2 10 35  2 31]
# P_G_obj = [17  2 47 19 23  2 10 35  2 31]
# fitness = 44476.89322461531
#
#
# Generation24
# Agent 0 before sorting [ 14 -28  33   1 -49  13 -16 -23  44  44]
#
# Agent 0 after sorting [ 14 -28  33   1 -49  13 -16 -23  44  44]
#
# 10
# 5
# initial P_G_obj =  [11 46 41 33 32 23 45 16 32 29]
# P_G_obj after controller =  [11 46 41 33 32 23 45 16 32 29]
# P_G_obj = [11 46 41 33 32 23 45 16 32 29]
# fitness = 564.6675812398042
# initial P_G_obj =  [ 4 15 40 34  3 24  5 10  5 34]
# P_G_obj after controller =  [ 4 15 40 34  3 24  5 10  5 34]
# P_G_obj = [ 4 15 40 34  3 24  5 10  5 34]
# fitness = 47113.53695095741
# initial P_G_obj =  [ 4 20 48 27  6 48 13 32 13 24]
# P_G_obj after controller =  [ 4 20 48 27  6 48 13 32 13 24]
# P_G_obj = [ 4 20 48 27  6 48 13 32 13 24]
# fitness = 35663.635266634126
# initial P_G_obj =  [40 26 17 21 11 44 12 12 11 13]
# P_G_obj after controller =  [40 26 17 21 11 44 12 12 11 13]
# P_G_obj = [40 26 17 21 11 44 12 12 11 13]
# fitness = 31430.66242411547
#
#
# Generation25
# Agent 0 before sorting [ 23 -28  33   1 -49  13 -45 -23  -6  44]
#
# Agent 0 after sorting [ 23 -28  33   1 -49  13 -45 -23  -6  44]
#
# 9
# 4
# initial P_G_obj =  [29 10 41 34 18 42 14 40 23 30]
# P_G_obj after controller =  [29 10 41 34 18 42 14 40 23 30]
# P_G_obj = [29 10 41 34 18 42 14 40 23 30]
# fitness = 13660.947539577992
# initial P_G_obj =  [43 30 43 21 47 32 48 29 19 35]
# P_G_obj after controller =  [43 30 43 21 47 32 48 29 19 35]
# P_G_obj = [43 30 43 21 47 32 48 29 19 35]
# fitness = -16018.206945602124
# initial P_G_obj =  [ 1 40 41  7 13 15 47 38 10  8]
# P_G_obj after controller =  [ 1 40 41  7 13 15 47 38 10  8]
# P_G_obj = [ 1 40 41  7 13 15 47 38 10  8]
# fitness = 33313.8318979876
# initial P_G_obj =  [44 23 14 43  1 27  1 28 47 23]
# P_G_obj after controller =  [ 44  23  14  43   1  27   1  28 -36  23]
# P_G_obj = [ 44  23  14  43   1  27   1  28 -36  23]
# fitness = 24071.947234748972
# initial P_G_obj =  [ 6 48 47 10 27 23 19 22 39  7]
# P_G_obj after controller =  [ 6 48 47 10 27 23 19 22 39  7]
# P_G_obj = [ 6 48 47 10 27 23 19 22 39  7]
# fitness = 27197.24716105153
# initial P_G_obj =  [48 43 32 29 20 34 48 47 34 37]
# P_G_obj after controller =  [48 43 32 29 20 34 48 47 34 37]
# P_G_obj = [48 43 32 29 20 34 48 47 34 37]
# fitness = -28201.179788120782
#
#
# Generation26
# Agent 0 before sorting [ 23  12  33   1 -49  13 -45  16  -6  44]
#
# Agent 0 after sorting [-46  20  20  28  37 -11   7 -23  -6  44]
#
# 10
# 5
# initial P_G_obj =  [12 11 12 11 15 41 43 44 47 18]
# P_G_obj after controller =  [ 12  11  12  11  15  41  43  44 -36  18]
# P_G_obj = [ 12  11  12  11  15  41  43  44 -36  18]
# fitness = 22318.669613632464
# initial P_G_obj =  [12 42  1 28 38  5 34 34 24  5]
# P_G_obj after controller =  [12 42  1 28 38  5 34 34 24  5]
# P_G_obj = [12 42  1 28 38  5 34 34 24  5]
# fitness = 29413.979371502694
# initial P_G_obj =  [25 30 35 49 36 29 16  4  2 39]
# P_G_obj after controller =  [25 30 35 49 36 29 16  4  2 39]
# P_G_obj = [25 30 35 49 36 29 16  4  2 39]
# fitness = 20430.760739792207
# initial P_G_obj =  [19  4 19 39 48 46 21 48 43 25]
# P_G_obj after controller =  [ 19   4  19  39  48  46  21  48 -36  25]
# P_G_obj = [ 19   4  19  39  48  46  21  48 -36  25]
# fitness = 18768.423824440622
#
#
# Generation27
# Agent 0 before sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# Agent 0 after sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# 9
# 4
# initial P_G_obj =  [11 48 30  4  2 34 42 14 40 40]
# P_G_obj after controller =  [11 48 30  4  2 34 42 14 40 40]
# P_G_obj = [11 48 30  4  2 34 42 14 40 40]
# fitness = 881.5964230444212
# initial P_G_obj =  [ 6 44 28 45  9 17 37 25 25 45]
# P_G_obj after controller =  [ 6 44 28 45  9 17 37 25 25 45]
# P_G_obj = [ 6 44 28 45  9 17 37 25 25 45]
# fitness = 6147.935370788648
# initial P_G_obj =  [13 46 37 18 40 47  8 16 25 42]
# P_G_obj after controller =  [13 46 37 18 40 47  8 16 25 42]
# P_G_obj = [13 46 37 18 40 47  8 16 25 42]
# fitness = 14080.859055468938
# initial P_G_obj =  [21 23  1  7  5 23 22 33 25 14]
# P_G_obj after controller =  [21 23  1  7  5 23 22 33 25 14]
# P_G_obj = [21 23  1  7  5 23 22 33 25 14]
# fitness = 34080.760739792204
# initial P_G_obj =  [46 13 39 10 46 20 28 12 36 29]
# P_G_obj after controller =  [46 13 39 10 46 20 28 12 36 29]
# P_G_obj = [46 13 39 10 46 20 28 12 36 29]
# fitness = -3518.305261278855
# initial P_G_obj =  [10  1 10 23  8 31 18 29 34 17]
# P_G_obj after controller =  [10  1 10 23  8 31 18 29 34 17]
# P_G_obj = [10  1 10 23  8 31 18 29 34 17]
# fitness = 38627.18817164551
#
#
# Generation28
# Agent 0 before sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# Agent 0 after sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# 10
# 5
# initial P_G_obj =  [45 11  4 19 42 28 18 15 40 22]
# P_G_obj after controller =  [45 11  4 19 42 28 18 15 40 22]
# P_G_obj = [45 11  4 19 42 28 18 15 40 22]
# fitness = 7711.439117961645
# initial P_G_obj =  [41 43 19 41 14  6 12 43 11  6]
# P_G_obj after controller =  [41 43 19 41 14  6 12 43 11  6]
# P_G_obj = [41 43 19 41 14  6 12 43 11  6]
# fitness = 29380.564108438743
# initial P_G_obj =  [15 14 27 26 16  0 14 11 48 26]
# P_G_obj after controller =  [ 15  14  27  26  16   0  14  11 -36  26]
# P_G_obj = [ 15  14  27  26  16   0  14  11 -36  26]
# fitness = 37305.067550782725
# initial P_G_obj =  [45 16 11 16  2 33 48 38 42 17]
# P_G_obj after controller =  [45 16 11 16  2 33 48 38 42 17]
# P_G_obj = [45 16 11 16  2 33 48 38 42 17]
# fitness = -6851.425577312602
#
#
# Generation29
# Agent 0 before sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# Agent 0 after sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# 9
# 4
# initial P_G_obj =  [22 28  2 39  4 48 42 48 24 40]
# P_G_obj after controller =  [22 28  2 39  4 48 42 48 24 40]
# P_G_obj = [22 28  2 39  4 48 42 48 24 40]
# fitness = -2001.8188400195231
# initial P_G_obj =  [44  8 27 47 32 28  6 11 12 20]
# P_G_obj after controller =  [44  8 27 47 32 28  6 11 12 20]
# P_G_obj = [44  8 27 47 32 28  6 11 12 20]
# fitness = 26694.018697773383
# initial P_G_obj =  [30 45 20  5 44 39 31 43 44 22]
# P_G_obj after controller =  [ 30  45  20   5  44  39  31  43 -36  22]
# P_G_obj = [ 30  45  20   5  44  39  31  43 -36  22]
# fitness = 7072.193023940794
# initial P_G_obj =  [32 14 12 14 24 27 26  4 25 23]
# P_G_obj after controller =  [32 14 12 14 24 27 26  4 25 23]
# P_G_obj = [32 14 12 14 24 27 26  4 25 23]
# fitness = 20831.15400249913
# initial P_G_obj =  [48  3 37  3  3 15 19 38 23  5]
# P_G_obj after controller =  [48  3 37  3  3 15 19 38 23  5]
# P_G_obj = [48  3 37  3  3 15 19 38 23  5]
# fitness = 29777.483118675693
# initial P_G_obj =  [21 39 20 15 14  4  1  7  7 17]
# P_G_obj after controller =  [21 39 20 15 14  4  1  7  7 17]
# P_G_obj = [21 39 20 15 14  4  1  7  7 17]
# fitness = 52230.17084573183
#
#
# Generation30
# Agent 0 before sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# Agent 0 after sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# 10
# 5
# initial P_G_obj =  [40 10  3 24 39 48 45 28 23 36]
# P_G_obj after controller =  [40 10  3 24 39 48 45 28 23 36]
# P_G_obj = [40 10  3 24 39 48 45 28 23 36]
# fitness = -6988.265935008159
# initial P_G_obj =  [20 31  7 21 46 15 33 18 30 44]
# P_G_obj after controller =  [20 31  7 21 46 15 33 18 30 44]
# P_G_obj = [20 31  7 21 46 15 33 18 30 44]
# fitness = 3181.498107367683
# initial P_G_obj =  [ 1  1 38 36 37  0 12 43 48 30]
# P_G_obj after controller =  [  1   1  38  36  37   0  12  43 -36  30]
# P_G_obj = [  1   1  38  36  37   0  12  43 -36  30]
# fitness = 39001.347509120926
# initial P_G_obj =  [24 46  4 28 38 49 42  7  5 24]
# P_G_obj after controller =  [24 46  4 28 38 49 42  7  5 24]
# P_G_obj = [24 46  4 28 38 49 42  7  5 24]
# fitness = 15147.640423758456
#
#
# Generation31
# Agent 0 before sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# Agent 0 after sorting [-46  27  20  28  37 -11   7 -23  -6  44]
#
# 9
# 4
# initial P_G_obj =  [32 25 47  6 32 42 37 46 15 35]
# P_G_obj after controller =  [32 25 47  6 32 42 37 46 15 35]
# P_G_obj = [32 25 47  6 32 42 37 46 15 35]
# fitness = -1551.9663135346318
# initial P_G_obj =  [44 41  0  6 26 36 22 31 27 42]
# P_G_obj after controller =  [44 41  0  6 26 36 22 31 27 42]
# P_G_obj = [44 41  0  6 26 36 22 31 27 42]
# fitness = -1385.0374717300094
# initial P_G_obj =  [29 23 12 39 14 48 44  1  4 44]
# P_G_obj after controller =  [29 23 12 39 14 48 44  1  4 44]
# P_G_obj = [29 23 12 39 14 48 44  1  4 44]
# fitness = 6531.399791690955
# initial P_G_obj =  [ 2  9 24 32 28 11 30 11 19  6]
# P_G_obj after controller =  [ 2  9 24 32 28 11 30 11 19  6]
# P_G_obj = [ 2  9 24 32 28 11 30 11 19  6]
# fitness = 45343.62543506647
# initial P_G_obj =  [36 49 43 33 22 13 48 25  0 30]
# P_G_obj after controller =  [36 49 43 33 22 13 48 25  0 30]
# P_G_obj = [36 49 43 33 22 13 48 25  0 30]
# fitness = 3064.6184234014363
# initial P_G_obj =  [27  3 44 41 27 45 26 16 36  2]
# P_G_obj after controller =  [27  3 44 41 27 45 26 16 36  2]
# P_G_obj = [27  3 44 41 27 45 26 16 36  2]
# fitness = 20360.750908224538
#
#
# Generation32
# Agent 0 before sorting [-46  27 -23  28  37 -11   7 -23 -33  44]
#
# Agent 0 after sorting [-46  27 -23  28  37 -11   7 -23 -33  44]
#
# 10
# 5
# initial P_G_obj =  [ 7  7 38 33  9  2 26 37 10 48]
# P_G_obj after controller =  [ 7  7 38 33  9  2 26 37 10 48]
# P_G_obj = [ 7  7 38 33  9  2 26 37 10 48]
# fitness = 26327.483118675696
# initial P_G_obj =  [24  2 40 16 20 45 46 37 28 15]
# P_G_obj after controller =  [24  2 40 16 20 45 46 37 28 15]
# P_G_obj = [24  2 40 16 20 45 46 37 28 15]
# fitness = 11411.09501309309
# initial P_G_obj =  [25 48 35 22 42 19 45 43 25 15]
# P_G_obj after controller =  [25 48 35 22 42 19 45 43 25 15]
# P_G_obj = [25 48 35 22 42 19 45 43 25 15]
# fitness = 1597.8862129502807
# initial P_G_obj =  [12  4 43 23 48 35 27 14  6 47]
# P_G_obj after controller =  [12  4 43 23 48 35 27 14  6 47]
# P_G_obj = [12  4 43 23 48 35 27 14  6 47]
# fitness = 20794.11701345012
#
#
# Generation33
# Agent 0 before sorting [-46  27 -10  28  37 -11   7 -23 -33  44]
#
# Agent 0 after sorting [-46  27 -10  28  37 -11   7 -23 -33  44]
#
# 9
# 4
# initial P_G_obj =  [ 6 24 47 25  0 30 42 40 30 41]
# P_G_obj after controller =  [ 6 24 47 25  0 30 42 40 30 41]
# P_G_obj = [ 6 24 47 25  0 30 42 40 30 41]
# fitness = 3248.033686465379
# initial P_G_obj =  [38 19 37 49 35  6 17 12  7 41]
# P_G_obj after controller =  [38 19 37 49 35  6 17 12  7 41]
# P_G_obj = [38 19 37 49 35  6 17 12  7 41]
# fitness = 12981.104844660771
# initial P_G_obj =  [12 16 26 21 38 28 11 17  3 45]
# P_G_obj after controller =  [12 16 26 21 38 28 11 17  3 45]
# P_G_obj = [12 16 26 21 38 28 11 17  3 45]
# fitness = 31847.24716105154
# initial P_G_obj =  [10 19 39  8 13 32 15 12 37  6]
# P_G_obj after controller =  [10 19 39  8 13 32 15 12 37  6]
# P_G_obj = [10 19 39  8 13 32 15 12 37  6]
# fitness = 36897.19800321317
# initial P_G_obj =  [44 22 46  7 14 10 24 36  9 20]
# P_G_obj after controller =  [44 22 46  7 14 10 24 36  9 20]
# P_G_obj = [44 22 46  7 14 10 24 36  9 20]
# fitness = 19631.00652898404
# initial P_G_obj =  [46 30  8 34 32  2 15 27 39 24]
# P_G_obj after controller =  [46 30  8 34 32  2 15 27 39 24]
# P_G_obj = [46 30  8 34 32  2 15 27 39 24]
# fitness = 5531.44894952932
#
#
# Generation34
# Agent 0 before sorting [-46  27 -10  40  37 -11   7 -23 -33  44]
#
# Agent 0 after sorting [-46  27 -10  40  37 -11   7 -23 -33  44]
#
# 10
# 5
# initial P_G_obj =  [43  0 45 18  5  9 13 17 48 17]
# P_G_obj after controller =  [ 43   0  45  18   5   9  13  17 -36  17]
# P_G_obj = [ 43   0  45  18   5   9  13  17 -36  17]
# fitness = 32535.156034891785
# initial P_G_obj =  [15 32 36 11 20 28  6 13 14  3]
# P_G_obj after controller =  [15 32 36 11 20 28  6 13 14  3]
# P_G_obj = [15 32 36 11 20 28  6 13 14  3]
# fitness = 50346.70642482953
# initial P_G_obj =  [28 28  3 11  4 28 22 12 47  1]
# P_G_obj after controller =  [ 28  28   3  11   4  28  22  12 -36   1]
# P_G_obj = [ 28  28   3  11   4  28  22  12 -36   1]
# fitness = 40638.33534033157
# initial P_G_obj =  [35 33  3 12 29 17 45 27 39 25]
# P_G_obj after controller =  [35 33  3 12 29 17 45 27 39 25]
# P_G_obj = [35 33  3 12 29 17 45 27 39 25]
# fitness = -3334.8899982149096
#
#
# Generation35
# Agent 0 before sorting [-46 -20 -10  40  37 -11   7 -23 -33  44]
#
# Agent 0 after sorting [-46 -20 -10  40  37 -11   7 -23 -33  44]
#
# 9
# 4
# initial P_G_obj =  [49 23 28  8 48 26 29 12 10  1]
# P_G_obj after controller =  [49 23 28  8 48 26 29 12 10  1]
# P_G_obj = [49 23 28  8 48 26 29 12 10  1]
# fitness = 22397.542108081725
# initial P_G_obj =  [ 9 27 18 44 34 22  2 15 29 25]
# P_G_obj after controller =  [ 9 27 18 44 34 22  2 15 29 25]
# P_G_obj = [ 9 27 18 44 34 22  2 15 29 25]
# fitness = 32947.1488453748
# initial P_G_obj =  [ 6 16 34 33 22 28 27  5  3  3]
# P_G_obj after controller =  [ 6 16 34 33 22 28 27  5  3  3]
# P_G_obj = [ 6 16 34 33 22 28 27  5  3  3]
# fitness = 50113.38947744232
# initial P_G_obj =  [22 33 42 44 33  3 30 46 40 44]
# P_G_obj after controller =  [22 33 42 44 33  3 30 46 40 44]
# P_G_obj = [22 33 42 44 33  3 30 46 40 44]
# fitness = -11068.35441911722
# initial P_G_obj =  [ 3 14 30 15 24 27 10  9  4 40]
# P_G_obj after controller =  [ 3 14 30 15 24 27 10  9  4 40]
# P_G_obj = [ 3 14 30 15 24 27 10  9  4 40]
# fitness = 43363.684424472514
# initial P_G_obj =  [36 20  3  8 19 33 30  6 41 21]
# P_G_obj after controller =  [36 20  3  8 19 33 30  6 41 21]
# P_G_obj = [36 20  3  8 19 33 30  6 41 21]
# fitness = 9998.18115998047
#
#
# Generation36
# Agent 0 before sorting [-46  30 -44  40  37 -11   7 -23 -33  44]
#
# Agent 0 after sorting [-46  30 -44  40  37 -11   7 -23 -33  44]
#
# 10
# 5
# initial P_G_obj =  [ 1  2 31 48 14 14 11 20 38  5]
# P_G_obj after controller =  [ 1  2 31 48 14 14 11 20 38  5]
# P_G_obj = [ 1  2 31 48 14 14 11 20 38  5]
# fitness = 46993.47796155137
# initial P_G_obj =  [ 5 26 26 14  8 39 18 29 43 15]
# P_G_obj after controller =  [  5  26  26  14   8  39  18  29 -36  15]
# P_G_obj = [  5  26  26  14   8  39  18  29 -36  15]
# fitness = 39171.45565636532
# initial P_G_obj =  [32 48 41  1 43 45 43  6 39 21]
# P_G_obj after controller =  [32 48 41  1 43 45 43  6 39 21]
# P_G_obj = [32 48 41  1 43 45 43  6 39 21]
# fitness = -7985.037471730011
# initial P_G_obj =  [42 16  3 17 21 19 33 35 36 19]
# P_G_obj after controller =  [42 16  3 17 21 19 33 35 36 19]
# P_G_obj = [42 16  3 17 21 19 33 35 36 19]
# fitness = 5631.547265206049
#
#
# Generation37
# Agent 0 before sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# Agent 0 after sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# 9
# 4
# initial P_G_obj =  [36 18 43 13  3 37 49 47  1 12]
# P_G_obj after controller =  [36 18 43 13  3 37 49 47  1 12]
# P_G_obj = [36 18 43 13  3 37 49 47  1 12]
# fitness = 15197.689581596822
# initial P_G_obj =  [32 19 19  5  1 14 34 12 27 20]
# P_G_obj after controller =  [32 19 19  5  1 14 34 12 27 20]
# P_G_obj = [32 19 19  5  1 14 34 12 27 20]
# fitness = 20847.93537078865
# initial P_G_obj =  [47 32  2 42 30 37 48 31 21  5]
# P_G_obj after controller =  [47 32  2 42 30 37 48 31 21  5]
# P_G_obj = [47 32  2 42 30 37 48 31 21  5]
# fitness = 981.3997916909568
# initial P_G_obj =  [33 12 14 43 36 27 32 35  9 24]
# P_G_obj after controller =  [33 12 14 43 36 27 32 35  9 24]
# P_G_obj = [33 12 14 43 36 27 32 35  9 24]
# fitness = 14527.679750029154
# initial P_G_obj =  [27 45 46 14 25 35 16 39 44 49]
# P_G_obj after controller =  [ 27  45  46  14  25  35  16  39 -36  49]
# P_G_obj = [ 27  45  46  14  25  35  16  39 -36  49]
# fitness = 1072.3404974558964
# initial P_G_obj =  [36 10  6 32 37  2 20 31 16 28]
# P_G_obj after controller =  [36 10  6 32 37  2 20 31 16 28]
# P_G_obj = [36 10  6 32 37  2 20 31 16 28]
# fitness = 21577.679750029143
#
#
# Generation38
# Agent 0 before sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# Agent 0 after sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# 10
# 5
# initial P_G_obj =  [38 38 12 39 41 38 13  7 24 41]
# P_G_obj after controller =  [38 38 12 39 41 38 13  7 24 41]
# P_G_obj = [38 38 12 39 41 38 13  7 24 41]
# fitness = 3497.9845286270156
# initial P_G_obj =  [22 31 19 22 25  2 19  6 25 31]
# P_G_obj after controller =  [22 31 19 22 25  2 19  6 25 31]
# P_G_obj = [22 31 19 22 25  2 19  6 25 31]
# fitness = 24131.006528984035
# initial P_G_obj =  [25 46 35 42 20  4 32 29  5  5]
# P_G_obj after controller =  [25 46 35 42 20  4 32 29  5  5]
# P_G_obj = [25 46 35 42 20  4 32 29  5  5]
# fitness = 29480.514950600376
# initial P_G_obj =  [12 32 12 23 40  3 30 36  6 43]
# P_G_obj after controller =  [12 32 12 23 40  3 30 36  6 43]
# P_G_obj = [12 32 12 23 40  3 30 36  6 43]
# fitness = 21180.908213307306
#
#
# Generation39
# Agent 0 before sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# Agent 0 after sorting [-46  30 -44  -4  37 -11   7 -23   3  44]
#
# 9
# 4
# initial P_G_obj =  [17 44  1 34 45  2 14 36 49 30]
# P_G_obj after controller =  [ 17  44   1  34  45   2  14  36 -36  30]
# P_G_obj = [ 17  44   1  34  45   2  14  36 -36  30]
# fitness = 23905.165866459458
# initial P_G_obj =  [ 9 44 32 35 45 31 39 12 21 12]
# P_G_obj after controller =  [ 9 44 32 35 45 31 39 12 21 12]
# P_G_obj = [ 9 44 32 35 45 31 39 12 21 12]
# fitness = 18564.077687179422
# initial P_G_obj =  [ 1  0 29 18 43 48  6 10  7 11]
# P_G_obj after controller =  [ 1  0 29 18 43 48  6 10  7 11]
# P_G_obj = [ 1  0 29 18 43 48  6 10  7 11]
# fitness = 60909.620277942144
# initial P_G_obj =  [30 14 43 19 17 25 12 49 20 20]
# P_G_obj after controller =  [30 14 43 19 17 25 12 49 20 20]
# P_G_obj = [30 14 43 19 17 25 12 49 20 20]
# fitness = 22830.760739792207
# initial P_G_obj =  [33  9 47 41  9 20 31 33 27 19]
# P_G_obj after controller =  [33  9 47 41  9 20 31 33 27 19]
# P_G_obj = [33  9 47 41  9 20 31 33 27 19]
# fitness = 10477.827223544244
# initial P_G_obj =  [48  9 33 40 32 33 26 45 11 31]
# P_G_obj after controller =  [48  9 33 40 32 33 26 45 11 31]
# P_G_obj = [48  9 33 40 32 33 26 45 11 31]
# fitness = 2327.925539220978
#
#
# Generation40
# Agent 0 before sorting [-46  30 -44  -4  37 -11   7  35   3  44]
#
# Agent 0 after sorting [-46  30 -44  -4  37 -11   7  35   3  44]
#
# 10
# 5
# initial P_G_obj =  [ 2  9 15 18 39  2  5 14  5 10]
# P_G_obj after controller =  [ 2  9 15 18 39  2  5 14  5 10]
# P_G_obj = [ 2  9 15 18 39  2  5 14  5 10]
# fitness = 66709.71859361888
# initial P_G_obj =  [47 21  5 21  6 31 35 29  3 34]
# P_G_obj after controller =  [47 21  5 21  6 31 35 29  3 34]
# P_G_obj = [47 21  5 21  6 31 35 29  3 34]
# fitness = 11198.033686465382
# initial P_G_obj =  [10 32 41 31  5 32 35 48 23 43]
# P_G_obj after controller =  [10 32 41 31  5 32 35 48 23 43]
# P_G_obj = [10 32 41 31  5 32 35 48 23 43]
# fitness = 4064.5692655630723
# initial P_G_obj =  [36 40 45 40  6 26  3 14 33 28]
# P_G_obj after controller =  [36 40 45 40  6 26  3 14 33 28]
# P_G_obj = [36 40 45 40  6 26  3 14 33 28]
# fitness = 12631.055686822398
#
#
# Generation41
# Agent 0 before sorting [-46 -11 -44  -4  37  49   7  35   3  44]
#
# Agent 0 after sorting [-46 -11 -44  -4  37  49   7  35   3  44]
#
# 9
# 4
# initial P_G_obj =  [10 38  9 37 38  5 47 43 27 29]
# P_G_obj after controller =  [10 38  9 37 38  5 47 43 27 29]
# P_G_obj = [10 38  9 37 38  5 47 43 27 29]
# fitness = 5847.935370788651
# initial P_G_obj =  [27 45 16 20 28  3  4 35  8 26]
# P_G_obj after controller =  [27 45 16 20 28  3  4 35  8 26]
# P_G_obj = [27 45 16 20 28  3  4 35  8 26]
# fitness = 34897.14884537481
# initial P_G_obj =  [19 36 45 47 46 30 45  7 16 18]
# P_G_obj after controller =  [19 36 45 47 46 30 45  7 16 18]
# P_G_obj = [19 36 45 47 46 30 45  7 16 18]
# fitness = 7697.689581596824
# initial P_G_obj =  [42 46 13 47 17 34 45 42 30 13]
# P_G_obj after controller =  [42 46 13 47 17 34 45 42 30 13]
# P_G_obj = [42 46 13 47 17 34 45 42 30 13]
# fitness = -7568.452734793949
# initial P_G_obj =  [13 38  4  3 43  5 45 39 11 20]
# P_G_obj after controller =  [13 38  4  3 43  5 45 39 11 20]
# P_G_obj = [13 38  4  3 43  5 45 39 11 20]
# fitness = 24347.54210808173
# initial P_G_obj =  [15 12 47 18 21 40 28 39 42 49]
# P_G_obj after controller =  [15 12 47 18 21 40 28 39 42 49]
# P_G_obj = [15 12 47 18 21 40 28 39 42 49]
# fitness = -6171.730355910468
#
#
# Generation42
# Agent 0 before sorting [-46 -11 -44  -4  37  49  22  35  43  44]
#
# Agent 0 after sorting [-46 -11 -44  -4  37  49  22  35  43  44]
#
# 10
# 5
# initial P_G_obj =  [ 3  3  9 31 38 31 32 49 39 24]
# P_G_obj after controller =  [ 3  3  9 31 38 31 32 49 39 24]
# P_G_obj = [ 3  3  9 31 38 31 32 49 39 24]
# fitness = 18877.532276514063
# initial P_G_obj =  [27 47 38 28 29 39 18  6 31 49]
# P_G_obj after controller =  [27 47 38 28 29 39 18  6 31 49]
# P_G_obj = [27 47 38 28 29 39 18  6 31 49]
# fitness = -3101.867997857891
# initial P_G_obj =  [12 11  9 13 41  8  1 15 16 29]
# P_G_obj after controller =  [12 11  9 13 41  8  1 15 16 29]
# P_G_obj = [12 11  9 13 41  8  1 15 16 29]
# fitness = 46743.674592904834
# initial P_G_obj =  [ 9  8 33 15 46 27 20 41  6 38]
# P_G_obj after controller =  [ 9  8 33 15 46 27 20 41  6 38]
# P_G_obj = [ 9  8 33 15 46 27 20 41  6 38]
# fitness = 28943.871224258288
#
#
# Generation43
# Agent 0 before sorting [-46 -11 -44  -4  37  49  22  35  43  44]
#
# Agent 0 after sorting [-46 -11 -44  -4  37  49  22  35  43  44]
#
# 9
# 4
# ...
# P_G_obj = [  4  41  13   2  42  28   5  12 -36   2]
# fitness = 54171.01323582003
# initial P_G_obj =  [43 30 47 13 28 44 24 12 39 25]
# P_G_obj after controller =  [43 30 47 13 28 44 24 12 39 25]
# P_G_obj = [43 30 47 13 28 44 24 12 39 25]
# fitness = -4351.7696821811605
# initial P_G_obj =  [ 2 25 14 28 43 40 33 26 14 23]
# P_G_obj after controller =  [ 2 25 14 28 43 40 33 26 14 23]
# P_G_obj = [ 2 25 14 28 43 40 33 26 14 23]
# fitness = 26813.93021366432
# initial P_G_obj =  [48 33 38 41 41 10 11  6 13 14]
# P_G_obj after controller =  [48 33 38 41 41 10 11  6 13 14]
# P_G_obj = [48 33 38 41 41 10 11  6 13 14]
# fitness = 20397.492950243362
# initial P_G_obj =  [14 17 11 15 40 33 24 14 16  2]
# P_G_obj after controller =  [14 17 11 15 40 33 24 14 16  2]
# P_G_obj = [14 17 11 15 40 33 24 14 16  2]
# fitness = 42247.00137185971
# initial P_G_obj =  [44 37 31 13  1 37  8 26 32 43]
# P_G_obj after controller =  [44 37 31 13  1 37  8 26 32 43]
# P_G_obj = [44 37 31 13  1 37  8 26 32 43]
# fitness = 2131.4981073676886
#
#
# Generation86
# Agent 0 before sorting [-46   6 -23  16  48  16 -43  -4   6  41]
#
# Agent 0 after sorting [-46   6 -23  16  48  16 -43  -4   6  41]
#
# 10
# 5
# initial P_G_obj =  [16  2  9 18 42  7 13  5 19 32]
# P_G_obj after controller =  [16  2  9 18 42  7 13  5 19 32]
# P_G_obj = [16  2  9 18 42  7 13  5 19 32]
# fitness = 40560.55427687109
# initial P_G_obj =  [44 33 42  8 33 32 44 19  7 29]
# P_G_obj after controller =  [44 33 42  8 33 32 44 19  7 29]
# P_G_obj = [44 33 42  8 33 32 44 19  7 29]
# fitness = 431.4489495293235
# initial P_G_obj =  [ 1 26  6 36 29 39 18 15 23 35]
# P_G_obj after controller =  [ 1 26  6 36 29 39 18 15 23 35]
# P_G_obj = [ 1 26  6 36 29 39 18 15 23 35]
# fitness = 27897.345476728264
# initial P_G_obj =  [45 45 13 41 15 40 43 41 46 24]
# P_G_obj after controller =  [ 45  45  13  41  15  40  43  41 -36  24]
# P_G_obj = [ 45  45  13  41  15  40  43  41 -36  24]
# fitness = -8243.99845028833
#
#
# Generation87
# Agent 0 before sorting [-46   6 -23  16 -10  16 -43  -4   6  41]
#
# Agent 0 after sorting [-46   6 -23  16 -10  16 -43  -4   6  41]
#
# 9
# 4
# initial P_G_obj =  [40 38 37 47 30 41 46 12  6 29]
# P_G_obj after controller =  [40 38 37 47 30 41 46 12  6 29]
# P_G_obj = [40 38 37 47 30 41 46 12  6 29]
# fitness = -3668.600208309047
# initial P_G_obj =  [ 5 49 48 12 40 42 43 28 20 39]
# P_G_obj after controller =  [ 5 49 48 12 40 42 43 28 20 39]
# P_G_obj = [ 5 49 48 12 40 42 43 28 20 39]
# fitness = 1697.8370551119208
# initial P_G_obj =  [20 46 47 26 30 23 25  5 43  1]
# P_G_obj after controller =  [ 20  46  47  26  30  23  25   5 -36   1]
# P_G_obj = [ 20  46  47  26  30  23  25   5 -36   1]
# fitness = 29654.920077267634
# initial P_G_obj =  [12 17 24 38 46 46 19  3 14 38]
# P_G_obj after controller =  [12 17 24 38 46 46 19  3 14 38]
# P_G_obj = [12 17 24 38 46 46 19  3 14 38]
# fitness = 21247.443792404996
# initial P_G_obj =  [39 41 41  7 31  7  8 35 12 25]
# P_G_obj after controller =  [39 41 41  7 31  7  8 35 12 25]
# P_G_obj = [39 41 41  7 31  7  8 35 12 25]
# fitness = 22514.12684501778
# initial P_G_obj =  [18 13 30 38 20  5 22  5 25  9]
# P_G_obj after controller =  [18 13 30 38 20  5 22  5 25  9]
# P_G_obj = [18 13 30 38 20  5 22  5 25  9]
# fitness = 35497.296318889894
#
#
# Generation88
# Agent 0 before sorting [-46   6 -23  16 -10  16  19  -4   6  41]
#
# Agent 0 after sorting [-46   6 -23  16 -10  16  19  -4   6  41]
#
# 10
# 5
# initial P_G_obj =  [28 15  4 13 23 16 29 11  1 30]
# P_G_obj after controller =  [28 15  4 13 23 16 29 11  1 30]
# P_G_obj = [28 15  4 13 23 16 29 11  1 30]
# fitness = 32380.859055468936
# initial P_G_obj =  [25 21 40 43  7 45 32  1 35 24]
# P_G_obj after controller =  [25 21 40 43  7 45 32  1 35 24]
# P_G_obj = [25 21 40 43  7 45 32  1 35 24]
# fitness = 6197.984528627014
# initial P_G_obj =  [44 41 46 35 49  3 13 48  0 42]
# P_G_obj after controller =  [44 41 46 35 49  3 13 48  0 42]
# P_G_obj = [44 41 46 35 49  3 13 48  0 42]
# fitness = 5514.372634209611
# initial P_G_obj =  [13 37 25 15 20 31 11 34 32 31]
# P_G_obj after controller =  [13 37 25 15 20 31 11 34 32 31]
# P_G_obj = [13 37 25 15 20 31 11 34 32 31]
# fitness = 20914.17600285615
#
#
# Generation89
# Agent 0 before sorting [-46   6 -23  16 -40  16 -13  -4   6  41]
#
# Agent 0 after sorting [-46   6 -23  16 -40  16 -13  -4   6  41]
#
# 9
# 4
# initial P_G_obj =  [47 20 47 43 17 20 43 36 35 23]
# P_G_obj after controller =  [47 20 47 43 17 20 43 36 35 23]
# P_G_obj = [47 20 47 43 17 20 43 36 35 23]
# fitness = -14768.157787763757
# initial P_G_obj =  [17 42 34 43  5 22 36  5 37 19]
# P_G_obj after controller =  [17 42 34 43  5 22 36  5 37 19]
# P_G_obj = [17 42 34 43  5 22 36  5 37 19]
# fitness = 10831.2031603375
# initial P_G_obj =  [37 18 21 48 48 27  6 49 23 34]
# P_G_obj after controller =  [37 18 21 48 48 27  6 49 23 34]
# P_G_obj = [37 18 21 48 48 27  6 49 23 34]
# fitness = 6631.055686822396
# initial P_G_obj =  [36 46 23 37 25  5 13 11 33 32]
# P_G_obj after controller =  [36 46 23 37 25  5 13 11 33 32]
# P_G_obj = [36 46 23 37 25  5 13 11 33 32]
# fitness = 8764.618423401433
# initial P_G_obj =  [ 6 17 15 43 33 30 30 10  3 41]
# P_G_obj after controller =  [ 6 17 15 43 33 30 30 10  3 41]
# P_G_obj = [ 6 17 15 43 33 30 30 10  3 41]
# fitness = 26747.394634566626
# initial P_G_obj =  [32 47 43 10 37  1 47 15 49  6]
# P_G_obj after controller =  [ 32  47  43  10  37   1  47  15 -36   6]
# P_G_obj = [ 32  47  43  10  37   1  47  15 -36   6]
# fitness = 12455.559129166377
#
#
# Generation90
# Agent 0 before sorting [-46   6  15  16 -40  16 -13  -4   6  41]
#
# Agent 0 after sorting [-46   6  15  16 -40  16 -13  -4   6  41]
#
# 10
# 5
# initial P_G_obj =  [21  9 16  4 24 38 42  9 22 40]
# P_G_obj after controller =  [21  9 16  4 24 38 42  9 22 40]
# P_G_obj = [21  9 16  4 24 38 42  9 22 40]
# fitness = 11328.07301273607
# initial P_G_obj =  [25  0 45 44  1  5 25  9 18 19]
# P_G_obj after controller =  [25  0 45 44  1  5 25  9 18 19]
# P_G_obj = [25  0 45 44  1  5 25  9 18 19]
# fitness = 34443.969539935024
# initial P_G_obj =  [18  6 38 21 20 40 15 44 30 19]
# P_G_obj after controller =  [18  6 38 21 20 40 15 44 30 19]
# P_G_obj = [18  6 38 21 20 40 15 44 30 19]
# fitness = 25060.652592547805
# initial P_G_obj =  [31 17  5 43 13 44 44 29 47 49]
# P_G_obj after controller =  [ 31  17   5  43  13  44  44  29 -36  49]
# P_G_obj = [ 31  17   5  43  13  44  44  29 -36  49]
# fitness = -8043.801818934875
#
#
# Generation91
# Agent 0 before sorting [-13   6  15  16 -40 -23 -13  -4   6  19]
#
# Agent 0 after sorting [-13   6  15  16 -40 -23 -13  -4   6  19]
#
# 9
# 4
# initial P_G_obj =  [48 16 34 17 35  4  6  4 11 26]
# P_G_obj after controller =  [48 16 34 17 35  4  6  4 11 26]
# P_G_obj = [48 16 34 17 35  4  6  4 11 26]
# fitness = 26580.908213307303
# initial P_G_obj =  [33 13  6 48  8 19 22 17 38  5]
# P_G_obj after controller =  [33 13  6 48  8 19 22 17 38  5]
# P_G_obj = [33 13  6 48  8 19 22 17 38  5]
# fitness = 22697.689581596824
# initial P_G_obj =  [49  5 35 36 15 26 45 48 37 40]
# P_G_obj after controller =  [49  5 35 36 15 26 45 48 37 40]
# P_G_obj = [49  5 35 36 15 26 45 48 37 40]
# fitness = -21421.238777526814
# initial P_G_obj =  [33 27 26 40  5  7  8 23 18 35]
# P_G_obj after controller =  [33 27 26 40  5  7  8 23 18 35]
# P_G_obj = [33 27 26 40  5  7  8 23 18 35]
# fitness = 22280.95737114567
# initial P_G_obj =  [34 22 44 12 16 45 27 21 17 30]
# P_G_obj after controller =  [34 22 44 12 16 45 27 21 17 30]
# P_G_obj = [34 22 44 12 16 45 27 21 17 30]
# fitness = 10014.52010772471
# initial P_G_obj =  [13  6 30 14 23 21  4 42 13  8]
# P_G_obj after controller =  [13  6 30 14 23 21  4 42 13  8]
# P_G_obj = [13  6 30 14 23 21  4 42 13  8]
# fitness = 53476.59827758512
#
#
# Generation92
# Agent 0 before sorting [-13   6  15  16 -40 -23 -13  -4   6  19]
#
# Agent 0 after sorting [-13   6  15  16 -40 -23 -13  -4   6  19]
#
# 10
# 5
# initial P_G_obj =  [48  3 47 39 48 18 26  2  2 34]
# P_G_obj after controller =  [48  3 47 39 48 18 26  2  2 34]
# P_G_obj = [48  3 47 39 48 18 26  2  2 34]
# fitness = 13077.728907867515
# initial P_G_obj =  [34  3 17 44 15 10 44 12 28  7]
# P_G_obj after controller =  [34  3 17 44 15 10 44 12 28  7]
# P_G_obj = [34  3 17 44 15 10 44 12 28  7]
# fitness = 19877.778065705876
# initial P_G_obj =  [15 15 20  6 38  2 19 23 21 43]
# P_G_obj after controller =  [15 15 20  6 38  2 19 23 21 43]
# P_G_obj = [15 15 20  6 38  2 19 23 21 43]
# fitness = 23747.689581596824
# initial P_G_obj =  [41 17 46 31  4 39 24  5 31 32]
# P_G_obj after controller =  [41 17 46 31  4 39 24  5 31 32]
# P_G_obj = [41 17 46 31  4 39 24  5 31 32]
# fitness = 2048.1811599804755
#
#
# Generation93
# Agent 0 before sorting [-13 -28  15  16 -40 -23 -13  -4   6  19]
#
# Agent 0 after sorting [-13 -28  15  16 -40 -23 -13  -4   6  19]
#
# 9
# 4
# initial P_G_obj =  [37 18 21 46  4 42 44 48  2 10]
# P_G_obj after controller =  [37 18 21 46  4 42 44 48  2 10]
# P_G_obj = [37 18 21 46  4 42 44 48  2 10]
# fitness = 15164.274318532873
# initial P_G_obj =  [18 24 29 28 43 14 26 40 28  1]
# P_G_obj after controller =  [18 24 29 28 43 14 26 40 28  1]
# P_G_obj = [18 24 29 28 43 14 26 40 28  1]
# fitness = 25980.61326627711
# initial P_G_obj =  [34  4  9 37  6 49 32 24 19 17]
# P_G_obj after controller =  [34  4  9 37  6 49 32 24 19 17]
# P_G_obj = [34  4  9 37  6 49 32 24 19 17]
# fitness = 21160.94753957799
# initial P_G_obj =  [39 41 43  0 38 23 23 35  1 44]
# P_G_obj after controller =  [39 41 43  0 38 23 23 35  1 44]
# P_G_obj = [39 41 43  0 38 23 23 35  1 44]
# fitness = 7547.837055111917
# initial P_G_obj =  [38 12  3  7 23 22 12 10 37 30]
# P_G_obj after controller =  [38 12  3  7 23 22 12 10 37 30]
# P_G_obj = [38 12  3  7 23 22 12 10 37 30]
# fitness = 17894.65774967213
# initial P_G_obj =  [37 27 20 28 25 20  6  5  5 29]
# P_G_obj after controller =  [37 27 20 28 25 20  6  5  5 29]
# P_G_obj = [37 27 20 28 25 20  6  5  5 29]
# fitness = 31797.34547672826
#
#
# Generation94
# Agent 0 before sorting [ 12  48  15  16 -40 -23 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  16 -40 -23 -13  -4   6  19]
#
# 10
# 5
# initial P_G_obj =  [31  6 39 44  7 17 49 39 23 15]
# P_G_obj after controller =  [31  6 39 44  7 17 49 39 23 15]
# P_G_obj = [31  6 39 44  7 17 49 39 23 15]
# fitness = 8411.242486608184
# initial P_G_obj =  [41 16 12 48 48 15  1 34  5 40]
# P_G_obj after controller =  [41 16 12 48 48 15  1 34  5 40]
# P_G_obj = [41 16 12 48 48 15  1 34  5 40]
# fitness = 19264.17600285615
# initial P_G_obj =  [15 48 27 46 49 25 47 19  2 14]
# P_G_obj after controller =  [15 48 27 46 49 25 47 19  2 14]
# P_G_obj = [15 48 27 46 49 25 47 19  2 14]
# fitness = 17914.028529341052
# initial P_G_obj =  [18 13 15 16 24 14 14 21 10 41]
# P_G_obj after controller =  [18 13 15 16 24 14 14 21 10 41]
# P_G_obj = [18 13 15 16 24 14 14 21 10 41]
# fitness = 31897.443792404993
#
#
# Generation95
# Agent 0 before sorting [ 12  48  15  16 -40 -23 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  16 -40 -23 -13  -4   6  19]
#
# 9
# 4
# initial P_G_obj =  [25 11 39 34 42 43 10 33 25 38]
# P_G_obj after controller =  [25 11 39 34 42 43 10 33 25 38]
# P_G_obj = [25 11 39 34 42 43 10 33 25 38]
# fitness = 9660.996697416362
# initial P_G_obj =  [47 34 23 10 28 20 38 13 17 11]
# P_G_obj after controller =  [47 34 23 10 28 20 38 13 17 11]
# P_G_obj = [47 34 23 10 28 20 38 13 17 11]
# fitness = 12147.93537078865
# initial P_G_obj =  [21 21 24 30  8 25 16 41 31 31]
# P_G_obj after controller =  [21 21 24 30  8 25 16 41 31 31]
# P_G_obj = [21 21 24 30  8 25 16 41 31 31]
# fitness = 16464.372634209612
# initial P_G_obj =  [17 36 26 34  0 47 47  1 31 42]
# P_G_obj after controller =  [17 36 26 34  0 47 47  1 31 42]
# P_G_obj = [17 36 26 34  0 47 47  1 31 42]
# fitness = -3051.6713665044244
# initial P_G_obj =  [39 39 10 28 48 46 44 40  7 49]
# P_G_obj after controller =  [39 39 10 28 48 46 44 40  7 49]
# P_G_obj = [39 39 10 28 48 46 44 40  7 49]
# fitness = -14168.305261278854
# initial P_G_obj =  [47 49 46 35  6  3 11 17 46 29]
# P_G_obj after controller =  [ 47  49  46  35   6   3  11  17 -36  29]
# P_G_obj = [ 47  49  46  35   6   3  11  17 -36  29]
# fitness = 10938.925234391954
#
#
# Generation96
# Agent 0 before sorting [ 12  48  15  16 -49 -23 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  16 -49 -23 -13  -4   6  19]
#
# 10
# 5
# initial P_G_obj =  [24 47 38 46 49 27 12  3 48 14]
# P_G_obj after controller =  [ 24  47  38  46  49  27  12   3 -36  14]
# P_G_obj = [ 24  47  38  46  49  27  12   3 -36  14]
# fitness = 22571.65228771878
# initial P_G_obj =  [15 42 12 17 30 11 28 25  2 25]
# P_G_obj after controller =  [15 42 12 17 30 11 28 25  2 25]
# P_G_obj = [15 42 12 17 30 11 28 25  2 25]
# fitness = 33730.564108438746
# initial P_G_obj =  [31 46  6 47 24 39 37 40  6 27]
# P_G_obj after controller =  [31 46  6 47 24 39 37 40  6 27]
# P_G_obj = [31 46  6 47 24 39 37 40  6 27]
# fitness = 7447.738739435186
# initial P_G_obj =  [ 0 34 11 13  5 28 24 31 46 19]
# P_G_obj after controller =  [  0  34  11  13   5  28  24  31 -36  19]
# P_G_obj = [  0  34  11  13   5  28  24  31 -36  19]
# fitness = 39504.87091942926
#
#
# Generation97
# Agent 0 before sorting [ 12  48  15  16 -49 -34 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  16 -49 -34 -13  -4   6  19]
#
# 9
# 4
# initial P_G_obj =  [20 45  4 19 17 10 17 19  7  4]
# P_G_obj after controller =  [20 45  4 19 17 10 17 19  7  4]
# P_G_obj = [20 45  4 19 17 10 17 19  7  4]
# fitness = 48913.536950957416
# initial P_G_obj =  [25 24 16  3 32 11 13 16 33 34]
# P_G_obj after controller =  [25 24 16  3 32 11 13 16 33 34]
# P_G_obj = [25 24 16  3 32 11 13 16 33 34]
# fitness = 20314.470949886345
# initial P_G_obj =  [21 13 16 26  2 13 33  4 13 11]
# P_G_obj after controller =  [21 13 16 26  2 13 33  4 13 11]
# P_G_obj = [21 13 16 26  2 13 33  4 13 11]
# fitness = 38914.02852934104
# initial P_G_obj =  [21 25 30 21 47 47 37 31 38 34]
# P_G_obj after controller =  [21 25 30 21 47 47 37 31 38 34]
# P_G_obj = [21 25 30 21 47 47 37 31 38 34]
# fitness = -7868.452734793955
# initial P_G_obj =  [25  1 14 25 12 28  1 32  4 42]
# P_G_obj after controller =  [25  1 14 25 12 28  1 32  4 42]
# P_G_obj = [25  1 14 25 12 28  1 32  4 42]
# fitness = 40860.40680335598
# initial P_G_obj =  [34 28 44  5 17 47 43  2 12 25]
# P_G_obj after controller =  [34 28 44  5 17 47 43  2 12 25]
# P_G_obj = [34 28 44  5 17 47 43  2 12 25]
# fitness = 9364.618423401436
#
#
# Generation98
# Agent 0 before sorting [ 12  48  15  47 -49 -34 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  47 -49 -34 -13  -4   6  19]
#
# 10
# 5
# initial P_G_obj =  [14 46 32  2 36 26 38 21 49 30]
# P_G_obj after controller =  [ 14  46  32   2  36  26  38  21 -36  30]
# P_G_obj = [ 14  46  32   2  36  26  38  21 -36  30]
# fitness = 12555.509971328018
# initial P_G_obj =  [36 43 47 47 40  5 30  2 41 46]
# P_G_obj after controller =  [36 43 47 47 40  5 30  2 41 46]
# P_G_obj = [36 43 47 47 40  5 30  2 41 46]
# fitness = -17584.74252469982
# initial P_G_obj =  [25 34 37  8 11 18 42 21 42 48]
# P_G_obj after controller =  [25 34 37  8 11 18 42 21 42 48]
# P_G_obj = [25 34 37  8 11 18 42 21 42 48]
# fitness = -11468.01031424866
# initial P_G_obj =  [44 25 32 32 46  6 24 29 16 17]
# P_G_obj after controller =  [44 25 32 32 46  6 24 29 16 17]
# P_G_obj = [44 25 32 32 46  6 24 29 16 17]
# fitness = 12247.738739435188
#
#
# Generation99
# Agent 0 before sorting [ 12  48  15  47 -49 -34 -13  -4   6  19]
#
# Agent 0 after sorting [ 12  48  15  47 -49 -34 -13  -4   6  19]
#
# 9
# 4
# initial P_G_obj =  [ 5 28  6 32  8 12  7 32 26  4]
# P_G_obj after controller =  [ 5 28  6 32  8 12  7 32 26  4]
# P_G_obj = [ 5 28  6 32  8 12  7 32 26  4]
# fitness = 51513.43863528068
# initial P_G_obj =  [47  7 43 31 28 15 13  2 42 33]
# P_G_obj after controller =  [47  7 43 31 28 15 13  2 42 33]
# P_G_obj = [47  7 43 31 28 15 13  2 42 33]
# fitness = 2861.537433638376
# initial P_G_obj =  [31  0 43  9 13  3 48 15 40 32]
# P_G_obj after controller =  [31  0 43  9 13  3 48 15 40 32]
# P_G_obj = [31  0 43  9 13  3 48 15 40 32]
# fitness = 3461.684907153478
# initial P_G_obj =  [42  1 21 19  7  5 49 12  7 28]
# P_G_obj after controller =  [42  1 21 19  7  5 49 12  7 28]
# P_G_obj = [42  1 21 19  7  5 49 12  7 28]
# fitness = 19111.29164444655
# initial P_G_obj =  [49 34 19 48 13  4 36 28  4 15]
# P_G_obj after controller =  [49 34 19 48 13  4 36 28  4 15]
# P_G_obj = [49 34 19 48 13  4 36 28  4 15]
# fitness = 14247.787897273554
# initial P_G_obj =  [ 3 43  2 30  9  1 10 27 27 41]
# P_G_obj after controller =  [ 3 43  2 30  9  1 10 27 27 41]
# P_G_obj = [ 3 43  2 30  9  1 10 27 27 41]
# fitness = 31614.077687179426

# %%
print(P_G_obj_test)
print(k_buy)
# Out:
# [25 43]
# [4 3]

# %%
 
    #on part d'un P_G_obj initial, et d'un SOC initial
    #on déduit le E_G_obj initial
    #on a tous les inputs du controller: E_L, E_S, P_G_obj, E_G_obj, SOC
    
    #Algo gen:
    #on construit un P_G_obj random
    #on fait passer les inputs à la moulinette du controller, avec une boucle sur i (=sur chaque pas de temps d_t)
    #il nous sort les nouveaux E_G et SOC pour chaque pas de temps d_t, ainsi que le vecteur de coûts associés à P_G_obj
    
    #On somme le vec de coût, ça donne un indicateur qu'il faut minimiser. 
    
    #On pourra grapher E_G *3600/d_t et E_L+E_S pour voir l'action de la batterie
